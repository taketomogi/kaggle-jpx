# %%
import numpy as np
import pandas as pd
from kaggle_jpx_package import ScoringService
# import sys
# sys.path.append('/Users/mogitaketo/code/kaggle/jpx/src/kaggle_jpx_package')
# from processor import ScoringService

# %%
ss = ScoringService()
# ss.get_dataset()
df_merge = ss.get_df_merge(debug=True)

# %%
df_merge.tail()
# Out:
#                 RowId        Date  SecuritiesCode   Open   High    Low  Close  \
# 102001  20220221_1332  2022-02-21            1332  552.0  553.0  547.0  550.0
# 104001  20220222_1332  2022-02-22            1332  543.0  543.0  534.0  542.0
# 106001  20220224_1332  2022-02-24            1332  540.0  540.0  526.0  533.0
# 108001  20220225_1332  2022-02-25            1332  528.0  533.0  525.0  532.0
# 110001  20220228_1332  2022-02-28            1332  531.0  545.0  531.0  544.0
#
#          Volume  AdjustmentFactor  ExpectedDividend  ...     d_vol     range  \
# 102001  1260300               1.0               NaN  ...  0.569724  0.023214
# 104001  1651100               1.0               NaN  ...  0.740204  0.029091
# 106001  3108600               1.0               NaN  ...  1.335958  0.029520
# 108001  2349400               1.0               NaN  ...  0.980391  0.015009
# 110001  2437900               1.0               NaN  ...  1.006870  0.026316
#
# ...

# %%
# %debug
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.

# %% [markdown]
# ## todo
# - [x] pricesとprices_supを結合して使えるようにする 5/4
# - [x] classmethodじゃなくてinstance methodにかえる
# - [ ] テスト組む
